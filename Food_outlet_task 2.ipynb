# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("zomato_restaurants_in_India.csv")

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ARCHANA\Desktop\Product-Price-Revenue-Analysis

# %%
df = pd.read_csv("zomato_restaurants_in_India.csv")

# %%
df
# Out:
#           res_id                            name      establishment  \
# 0        3400299                     Bikanervala    ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2        3401013                   Bhagat Halwai    ['Quick Bites']
# 3        3400290                   Bhagat Halwai    ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# ...          ...                             ...                ...
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %%
df.head()
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  str
#  2   establishment         211944 non-null  str
#  3   url                   211944 non-null  str
#  4   address               211810 non-null  str
#  5   city                  211944 non-null  str
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  str
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   str
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  str
#  13  cuisines              210553 non-null  str
#  14  timings               208070 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# res_id                       0
# name                         0
# establishment                0
# url                          0
# address                    134
# city                         0
# city_id                      0
# locality                     0
# latitude                     0
# longitude                    0
# zipcode                 163187
# country_id                   0
# locality_verbose             0
# cuisines                  1391
# timings                   3874
# average_cost_for_two         0
# price_range                  0
# currency                     0
# highlights                   0
# aggregate_rating             0
# rating_text                  0
# votes                        0
# photo_count                  0
# opentable_support           48
# delivery                     0
# takeaway                     0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# res_id                  0
# name                    0
# establishment           0
# url                     0
# address                 0
# city                    0
# city_id                 0
# locality                0
# latitude                0
# longitude               0
# zipcode                 0
# country_id              0
# locality_verbose        0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# opentable_support       0
# delivery                0
# takeaway                0
# dtype: int64

# %%
city_count = df["city"].value_counts()

print(city_count)
# Out:
# city
# Chennai          5043
# Mumbai           3388
# Bangalore        2229
# Lucknow          2062
# Pune             1933
#                  ...
# Howrah             20
# Darjeeling         19
# Gangtok            17
# Udupi              10
# Greater Noida       9
# Name: count, Length: 96, dtype: int64

# %%
cuisine_count = df["cuisines"].value_counts().head(10)

print(cuisine_count)
# Out:
# cuisines
# North Indian                          2741
# North Indian, Chinese                 1159
# Cafe                                   984
# Fast Food                              825
# South Indian                           626
# Cafe, Fast Food                        571
# North Indian, Chinese, Continental     567
# Pizza, Fast Food                       550
# North Indian, Mughlai                  491
# Finger Food                            451
# Name: count, dtype: int64

# %%
top_restaurants = df.sort_values(by="aggregate_rating", ascending=False)[["name", "city", "aggregate_rating"]].head(10)

print(top_restaurants)
# Out:
#                      name      city  aggregate_rating
# 87380               Chool    Jaipur               4.9
# 211871      Indish Lounge  Vadodara               4.9
# 211890      Indish Lounge  Vadodara               4.9
# 211894      Indish Lounge  Vadodara               4.9
# 211627      Indish Lounge  Vadodara               4.9
# 197761  Traditional Khana   Udaipur               4.9
# 197877  Traditional Khana   Udaipur               4.9
# 40950      Coal Barbecues   Chennai               4.9
# 40955             Bhangra   Chennai               4.9
# 139168         Pot Pourri    Mumbai               4.9

# %%
average_rating = df["aggregate_rating"].mean()

print("Average Rating:", round(average_rating, 2))
# Out:
# Average Rating: 3.94

# %%
delivery_count = df["delivery"].value_counts()

print(delivery_count)
# Out:
# delivery
# -1    27911
#  1    20324
#  0      143
# Name: count, dtype: int64

# %%
city_count = df["city"].value_counts().head(10)

plt.figure(figsize=(10,5))
city_count.plot(kind="bar")

plt.title("Top 10 Cities with the Most Restaurants")
plt.xlabel("City")
plt.ylabel("Number of Restaurants")

plt.xticks(rotation=45)
plt.show()

# %%
cuisine_count = df["cuisines"].value_counts().head(10)

plt.figure(figsize=(10,5))
cuisine_count.plot(kind="bar")

plt.title("Top 10 Most Popular Cuisines")
plt.xlabel("Cuisine")
plt.ylabel("Number of Restaurants")

plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["aggregate_rating"], bins=10)

plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Aggregate Rating")
plt.ylabel("Number of Restaurants")

plt.show()

# %% [markdown]
# # Food Outlet Descriptive Analysis
#
# ## Import Libraries
#
# ## Load Dataset
#
# ## Display Dataset
#
# ## Data Cleaning
#
# ## Business Question 1
#
# ## Business Question 2
#
# ...
#
# ## Data Visualization
#
# ## Conclusion
#
# The analysis provided useful insights into restaurant data, including ratings, cuisines, cities, and delivery services. These findings can help businesses understand customer preferences and make better decisions.
